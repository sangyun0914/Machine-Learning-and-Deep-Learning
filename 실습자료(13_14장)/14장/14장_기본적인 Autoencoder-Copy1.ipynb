# %%
from keras.layers import Input, Dense
from keras.models import Model

encoding_dim = 32 

#인풋이미지는 한 인스턴스 당 28x28=784개의 feature를 가지므로 shape을 다음과 같이 정해준다.
input_img = Input(shape=(784,))

#인코더와 디코더를 각각 한 층으로 쌓아준다.
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

#최종 오토인코더 모형은 인풋부터 인코더, 디코더의 아웃풋까지 연결해준다.
autoencoder = Model(input_img, decoded)

# %%
#다음과 같이 인코더와 디코더를 분리해서 정의해놓는 것도 가능하다.
encoder = Model(input_img, encoded)
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

# %%
#MNIST dataset의 x입력값들을 28x28=784의 크기로 벡터화한다.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
#위에서 정의한 오토인코더 모형 학습
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2776 - val_loss: 0.1905
# Epoch 2/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1713 - val_loss: 0.1548
# Epoch 3/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1461 - val_loss: 0.1359
# Epoch 4/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1307 - val_loss: 0.1233
# Epoch 5/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1200 - val_loss: 0.1143
# Epoch 6/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1124 - val_loss: 0.1081
# Epoch 7/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1070 - val_loss: 0.1034
# Epoch 8/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.1032 - val_loss: 0.1003
# Epoch 9/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0996 - val_loss: 0.0968
# Epoch 10/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0973 - val_loss: 0.0952
# Epoch 11/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0960 - val_loss: 0.0942
# Epoch 12/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0952 - val_loss: 0.0935
# Epoch 13/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0946 - val_loss: 0.0930
# Epoch 14/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0942 - val_loss: 0.0929
# Epoch 15/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0940 - val_loss: 0.0926
# Epoch 16/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0938 - val_loss: 0.0924
# Epoch 17/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0936 - val_loss: 0.0923
# Epoch 18/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0935 - val_loss: 0.0922
# Epoch 19/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 20/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0933 - val_loss: 0.0920
# Epoch 21/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 22/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 23/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 24/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 25/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 26/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 27/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0930 - val_loss: 0.0917
# Epoch 28/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 29/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 30/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 31/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 32/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 33/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 34/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 35/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 36/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 37/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 38/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 39/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 40/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 41/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 42/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 43/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 44/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0927 - val_loss: 0.0919
# Epoch 45/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 46/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 47/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 48/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 49/50
# 235/235 [==============================] - 1s 2ms/step - loss: 0.0926 - val_loss: 0.0914
# Epoch 50/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0926 - val_loss: 0.0916

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
import matplotlib.pyplot as plt

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i+1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i+1+n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
