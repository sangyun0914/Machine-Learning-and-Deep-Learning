# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

# %%
#컨볼루션 오토인코더를 활용하여 Denoising
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
#가우스 노이즈 데이터 생성
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0, 1)
x_test_noisy = np.clip(x_test_noisy, 0, 1)

# %%
#노이즈 데이터 시각화
import matplotlib.pyplot as plt

n = 10
plt.figure(figsize=(20, 2))
for i in range(1,n+1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#컨볼루션 오토인코더를 활용
#Deep autoencoder를 활용해도 된다.(이 경우 인풋을 784로 맞춰야 한다.) 

from keras.layers import Conv2D, MaxPooling2D, UpSampling2D
input_img = Input(shape=(28, 28, 1))

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/50
# 59/59 [==============================] - 39s 667ms/step - loss: 0.3633 - val_loss: 0.2019
# Epoch 2/50
# 59/59 [==============================] - 39s 664ms/step - loss: 0.1724 - val_loss: 0.1531
# Epoch 3/50
# 59/59 [==============================] - 39s 667ms/step - loss: 0.1443 - val_loss: 0.1353
# Epoch 4/50
# 59/59 [==============================] - 39s 664ms/step - loss: 0.1324 - val_loss: 0.1274
# Epoch 5/50
# 59/59 [==============================] - 39s 664ms/step - loss: 0.1270 - val_loss: 0.1235
# Epoch 6/50
# 59/59 [==============================] - 39s 666ms/step - loss: 0.1235 - val_loss: 0.1213
# Epoch 7/50
# 59/59 [==============================] - 39s 664ms/step - loss: 0.1214 - val_loss: 0.1195
# Epoch 8/50
# 59/59 [==============================] - 39s 663ms/step - loss: 0.1193 - val_loss: 0.1175
# Epoch 9/50
# 59/59 [==============================] - 39s 667ms/step - loss: 0.1181 - val_loss: 0.1158
# Epoch 10/50
# 59/59 [==============================] - 38s 651ms/step - loss: 0.1164 - val_loss: 0.1155
# Epoch 11/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1154 - val_loss: 0.1136
# Epoch 12/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1141 - val_loss: 0.1125
# Epoch 13/50
# 59/59 [==============================] - 37s 633ms/step - loss: 0.1133 - val_loss: 0.1116
# Epoch 14/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1126 - val_loss: 0.1107
# Epoch 15/50
# 59/59 [==============================] - 37s 630ms/step - loss: 0.1116 - val_loss: 0.1099
# Epoch 16/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1108 - val_loss: 0.1093
# Epoch 17/50
# 59/59 [==============================] - 37s 632ms/step - loss: 0.1100 - val_loss: 0.1084
# Epoch 18/50
# 59/59 [==============================] - 37s 629ms/step - loss: 0.1094 - val_loss: 0.1080
# Epoch 19/50
# 59/59 [==============================] - 37s 632ms/step - loss: 0.1085 - val_loss: 0.1070
# Epoch 20/50
# 59/59 [==============================] - 37s 631ms/step - loss: 0.1079 - val_loss: 0.1064
# Epoch 21/50
# 59/59 [==============================] - 37s 629ms/step - loss: 0.1073 - val_loss: 0.1059
# Epoch 22/50
# 59/59 [==============================] - 37s 633ms/step - loss: 0.1068 - val_loss: 0.1055
# Epoch 23/50
# 59/59 [==============================] - 37s 633ms/step - loss: 0.1064 - val_loss: 0.1051
# Epoch 24/50
# 59/59 [==============================] - 37s 632ms/step - loss: 0.1061 - val_loss: 0.1046
# Epoch 25/50
# 59/59 [==============================] - 37s 635ms/step - loss: 0.1056 - val_loss: 0.1043
# Epoch 26/50
# 59/59 [==============================] - 38s 638ms/step - loss: 0.1052 - val_loss: 0.1042
# Epoch 27/50
# 59/59 [==============================] - 37s 632ms/step - loss: 0.1048 - val_loss: 0.1040
# Epoch 28/50
# 59/59 [==============================] - 37s 635ms/step - loss: 0.1045 - val_loss: 0.1033
# Epoch 29/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1041 - val_loss: 0.1035
# Epoch 30/50
# 59/59 [==============================] - 37s 633ms/step - loss: 0.1039 - val_loss: 0.1029
# Epoch 31/50
# 59/59 [==============================] - 37s 635ms/step - loss: 0.1035 - val_loss: 0.1028
# Epoch 32/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1033 - val_loss: 0.1023
# Epoch 33/50
# 59/59 [==============================] - 37s 633ms/step - loss: 0.1032 - val_loss: 0.1020
# Epoch 34/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1028 - val_loss: 0.1020
# Epoch 35/50
# 59/59 [==============================] - 38s 641ms/step - loss: 0.1027 - val_loss: 0.1017
# Epoch 36/50
# 59/59 [==============================] - 37s 633ms/step - loss: 0.1024 - val_loss: 0.1015
# Epoch 37/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1022 - val_loss: 0.1011
# Epoch 38/50
# 59/59 [==============================] - 37s 635ms/step - loss: 0.1020 - val_loss: 0.1010
# Epoch 39/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1019 - val_loss: 0.1009
# Epoch 40/50
# 59/59 [==============================] - 37s 634ms/step - loss: 0.1017 - val_loss: 0.1011
# Epoch 41/50
# 59/59 [==============================] - 37s 635ms/step - loss: 0.1015 - val_loss: 0.1006
# Epoch 42/50
# 59/59 [==============================] - 38s 648ms/step - loss: 0.1014 - val_loss: 0.1004
# Epoch 43/50
# 59/59 [==============================] - 38s 643ms/step - loss: 0.1012 - val_loss: 0.1002
# Epoch 44/50
# 59/59 [==============================] - 38s 644ms/step - loss: 0.1011 - val_loss: 0.1003
# Epoch 45/50
# 59/59 [==============================] - 38s 643ms/step - loss: 0.1010 - val_loss: 0.0999
# Epoch 46/50
# 59/59 [==============================] - 38s 645ms/step - loss: 0.1008 - val_loss: 0.0998
# Epoch 47/50
# 59/59 [==============================] - 38s 645ms/step - loss: 0.1007 - val_loss: 0.0999
# Epoch 48/50
# 59/59 [==============================] - 38s 647ms/step - loss: 0.1005 - val_loss: 0.0995
# Epoch 49/50
# 59/59 [==============================] - 38s 645ms/step - loss: 0.1004 - val_loss: 0.0994
# Epoch 50/50
# 59/59 [==============================] - 38s 644ms/step - loss: 0.1003 - val_loss: 0.0997

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1,n+1):
    ax = plt.subplot(1, n, i)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
